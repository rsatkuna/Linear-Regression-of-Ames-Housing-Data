# %%
# imports

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer, SimpleImputer
from scipy import stats
import os
import re
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, KFold
from sklearn.linear_model import LinearRegression

# %%
X_train = pd.read_csv('datasets_f/numZ_train.csv')
X_test = pd.read_csv('datasets_f/numZ_test.csv')
y_train = pd.read_csv('datasets_f/y_train.csv')
y_test =pd.read_csv('datasets_f/y_test.csv')

# %%
test = pd.read_csv('datasets_f/kagtest.csv')

# %%
high_num =['gr_liv_area','year_built','garage_area','total_bsmt_sf','full_bath']

# %%
X_train=X_train[high_num]

# %%
X_test=X_test[high_num]

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_train,y_train)
# Out:
# 0.7961889686329996

# %%
lr.score(X_test,y_test)
# Out:
# 0.8113119405454938

# %%
lr.predict(test[high_num])
# Out:
# array([[170993.35792505],
#        [265291.45351068],
#        [178101.77555744],
#        [110123.16043685],
#        [186169.68068852],
#        [116429.83342031],
#        [124550.60616025],
#        [163323.69888926],
#        [208804.4861475 ],
#        [173258.03278016],
#        [178596.9300696 ],
#        [110011.77330452],
#        [174410.2984576 ],
#        [313919.23670677],
#        [152763.41414235],
#        [ 98385.04314128],
#        [170410.39137081],
#        [133298.82951517],
#        [201752.68257829],
#        [136449.06423062],
#        [134480.91100471],
#        [135497.61564261],
#        [229640.09125343],
#        [140797.85209721],
#        [194844.90177805],
#        [118600.55363228],
#        [144577.99661682],
#        [111651.37486329],
#        [138298.24861079],
#        [ 44332.70704014],
#        [137690.74201173],
#        [123662.87440011],
#        [242389.79996133],
#        [161694.53007925],
#        [224694.94191009],
# ...

# %%
ptest=test.copy()

# %%
ptest.drop(columns= ['lot_frontage', 'lot_area', 'mas_vnr_area', 'bsmt_fin_sf_1',
       'bsmt_fin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf', '1st_flr_sf',
       '2nd_flr_sf', 'gr_liv_area', 'garage_area', 'wood_deck_sf',
       'open_porch_sf', 'enclosed_porch', '3ssn_porch', 'screen_porch',
       'pool_area', 'misc_val', 'year_built', 'year_remod/add',
       'bsmt_full_bath', 'bsmt_half_bath', 'full_bath', 'half_bath',
       'bedroom_abv_gr', 'kitchen_abv_gr', 'tot_rms_abv_grd', 'fireplaces',
       'garage_yr_blt', 'garage_cars', 'mo_sold', 'yr_sold'], axis=1, inplace=True)

# %%
ptest.head()
# Out:
#      id
# 0  2658
# 1  2718
# 2  2414
# 3  1989
# 4   625

# %%
predictions = pd.DataFrame(lr.predict(test[high_num]))

# %%
predictions.head()
# Out:
#                0
# 0  170993.357925
# 1  265291.453511
# 2  178101.775557
# 3  110123.160437
# 4  186169.680689

# %%
satkuna_kaggle = ptest.join(predictions[0])
# numZ_test = numZ_test.join(X_test['id'])
# aniz = numZ_test.pop('id')
# numZ_test.insert(0, 'id', aniz)

# %%
satkuna_kaggle = satkuna_kaggle.rename(columns={'id':'Id', 0:'sample_soln'})

# %%
satkuna_kaggle.shape
# Out:
# (878, 2)

# %%
satkuna_kaggle.head()
# Out:
#      Id    sample_soln
# 0  2658  170993.357925
# 1  2718  265291.453511
# 2  2414  178101.775557
# 3  1989  110123.160437
# 4   625  186169.680689

# %%
satkuna_kaggle=satkuna_kaggle

# %%
satkuna_kaggle=satkuna_kaggle.reset_index().drop(columns='Id')

# %%
satkuna_kaggle=satkuna_kaggle.rename(columns={'index':'Id'})

# %%
satkuna_kaggle=satkuna_kaggle[:260]

# %%
# Out:
#    Id    sample_soln
# 0   0  170993.357925
# 1   1  265291.453511
# 2   2  178101.775557
# 3   3  110123.160437
# 4   4  186169.680689

# %%
satkuna_kaggle.to_csv('kagglesub/satkuna_struggle_new.csv', index=False)
